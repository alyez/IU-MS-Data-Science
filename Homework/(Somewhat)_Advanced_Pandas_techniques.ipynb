# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Combining dataframes

# %% [markdown]
#  Create some toy data

# %%
df1 = pd.DataFrame({'Name': ['Tom Cruise', 'Robert Downey Jr', 'Chris Hemsworth', 'Jennifer Lawrence'],\
                   'Age':[56, 53, 35, 28 ],\
                   'Gender': ['Male', 'Male', 'Male', 'Female']})

# %%
df1
# Out:
#                 Name  Age  Gender
# 0         Tom Cruise   56    Male
# 1   Robert Downey Jr   53    Male
# 2    Chris Hemsworth   35    Male
# 3  Jennifer Lawrence   28  Female

# %%
df2 = pd.DataFrame({'Actor_name': ['Jennifer Lawrence','Tom Cruise', 'Johnny Depp', 'Kim Kardashian'],\
                  'Gender': ['Female', 'Male', 'Male', 'Female'],\
                  'Net_worth_millions': [60, 470, 400, 85]})

# %%
df2
# Out:
#           Actor_name  Gender  Net_worth_millions
# 0  Jennifer Lawrence  Female                  60
# 1         Tom Cruise    Male                 470
# 2        Johnny Depp    Male                 400
# 3     Kim Kardashian  Female                  85

# %% [markdown]
# Pandas `merge` allows us to join the two dataframes.
#
# Documentation: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html

# %% [markdown]
# Join by the name?

# %%
df = pd.merge(df1, df2, left_on = 'Name', right_on = 'Actor_name') #left_on and right_on specifies the column names we want to join on 
df
# Out:
#                 Name  Age Gender_x         Actor_name Gender_y  \
# 0         Tom Cruise   56     Male         Tom Cruise     Male
# 1  Jennifer Lawrence   28   Female  Jennifer Lawrence   Female
#
#    Net_worth_millions
# 0                 470
# 1                  60

# %% [markdown]
# Drop the duplicated columns?

# %%
df = df.drop(['Actor_name', 'Gender_y'],axis=1)
df
# Out:
#                 Name  Age Gender_x  Net_worth_millions
# 0         Tom Cruise   56     Male                 470
# 1  Jennifer Lawrence   28   Female                  60

# %% [markdown]
# The four types of `merge`

# %%
df = pd.merge(df1, df2, left_on = 'Name', right_on = 'Actor_name', how = 'left')
df
# Out:
#                 Name  Age Gender_x         Actor_name Gender_y  \
# 0         Tom Cruise   56     Male         Tom Cruise     Male
# 1   Robert Downey Jr   53     Male                NaN      NaN
# 2    Chris Hemsworth   35     Male                NaN      NaN
# 3  Jennifer Lawrence   28   Female  Jennifer Lawrence   Female
#
#    Net_worth_millions
# 0               470.0
# 1                 NaN
# 2                 NaN
# 3                60.0

# %%
df = pd.merge(df1, df2, left_on = 'Name', right_on = 'Actor_name', how = 'right') 
df
# Out:
#                 Name   Age Gender_x         Actor_name Gender_y  \
# 0         Tom Cruise  56.0     Male         Tom Cruise     Male
# 1  Jennifer Lawrence  28.0   Female  Jennifer Lawrence   Female
# 2                NaN   NaN      NaN        Johnny Depp     Male
# 3                NaN   NaN      NaN     Kim Kardashian   Female
#
#    Net_worth_millions
# 0                 470
# 1                  60
# 2                 400
# 3                  85

# %%
df = pd.merge(df1, df2, left_on = 'Name', right_on = 'Actor_name', how = 'outer') 
df
# Out:
#                 Name   Age Gender_x         Actor_name Gender_y  \
# 0         Tom Cruise  56.0     Male         Tom Cruise     Male
# 1   Robert Downey Jr  53.0     Male                NaN      NaN
# 2    Chris Hemsworth  35.0     Male                NaN      NaN
# 3  Jennifer Lawrence  28.0   Female  Jennifer Lawrence   Female
# 4                NaN   NaN      NaN        Johnny Depp     Male
# 5                NaN   NaN      NaN     Kim Kardashian   Female
#
#    Net_worth_millions
# 0               470.0
# 1                 NaN
# 2                 NaN
# 3                60.0
# 4               400.0
# 5                85.0

# %%
df = pd.merge(df1, df2, left_on = 'Name', right_on = 'Actor_name', how = 'inner') 
df
# Out:
#    Age Gender_x               Name         Actor_name Gender_y  \
# 0   56     Male         Tom Cruise         Tom Cruise     Male
# 1   28   Female  Jennifer Lawrence  Jennifer Lawrence   Female
#
#    Net_worth_millions
# 0                 470
# 1                  60

# %% [markdown]
# As we can see, the default method is `inner`.

# %% [markdown]
# Since the dataframes have two common columns, we can also join on both.

# %%
df = pd.merge(df1, df2, left_on = ['Name', 'Gender'], right_on = ['Actor_name', 'Gender'])
df
# Out:
#                 Name  Age  Gender         Actor_name  Net_worth_millions
# 0         Tom Cruise   56    Male         Tom Cruise                 470
# 1  Jennifer Lawrence   28  Female  Jennifer Lawrence                  60

# %% [markdown]
# ### `merge` vs `concatenate`? (union)

# %%
df = pd.concat([df1, df2])
df
# Out:
# C:\Users\yyezeret\AppData\Local\Continuum\Anaconda2\envs\dviz\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#           Actor_name   Age  Gender               Name  Net_worth_millions
# 0                NaN  56.0    Male         Tom Cruise                 NaN
# 1                NaN  53.0    Male   Robert Downey Jr                 NaN
# 2                NaN  35.0    Male    Chris Hemsworth                 NaN
# 3                NaN  28.0  Female  Jennifer Lawrence                 NaN
# 0  Jennifer Lawrence   NaN  Female                NaN                60.0
# 1         Tom Cruise   NaN    Male                NaN               470.0
# 2        Johnny Depp   NaN    Male                NaN               400.0
# 3     Kim Kardashian   NaN  Female                NaN                85.0

# %% [markdown]
# `concat` simply sticks the dataframes together.

# %% [markdown]
# We can also stick horizontally.

# %%
df = pd.concat([df1, df2], axis = 'columns')
df
# Out:
#                 Name  Age  Gender         Actor_name  Gender  \
# 0         Tom Cruise   56    Male  Jennifer Lawrence  Female
# 1   Robert Downey Jr   53    Male         Tom Cruise    Male
# 2    Chris Hemsworth   35    Male        Johnny Depp    Male
# 3  Jennifer Lawrence   28  Female     Kim Kardashian  Female
#
#    Net_worth_millions
# 0                  60
# 1                 470
# 2                 400
# 3                  85

# %% [markdown]
# ## Grouping data

# %% [markdown]
# load a slightly larger dataset.

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# What if we want to look at the data grouped by the sex of passengers?
#
# Documentation: http://pandas.pydata.org/pandas-docs/stable/groupby.html

# %%
grp = titanic.groupby('sex')
grp

# %%
grp.groups
# Out:
# {'female': Int64Index([  1,   2,   3,   8,   9,  10,  11,  14,  15,  18,
#              ...
#              866, 871, 874, 875, 879, 880, 882, 885, 887, 888],
#             dtype='int64', length=314),
#  'male': Int64Index([  0,   4,   5,   6,   7,  12,  13,  16,  17,  20,
#              ...
#              873, 876, 877, 878, 881, 883, 884, 886, 889, 890],
#             dtype='int64', length=577)}

# %%
for name, group in grp:
    print(name)
    print(group)
# Out:
# female
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
#
# 874         1       2  female  28.0      1      0   24.0000        C  Second
# 875         1       3  female  15.0      0      0    7.2250        C   Third
# 879         1       1  female  56.0      0      1   83.1583        C   First
# 880         1       2  female  25.0      0      1   26.0000        S  Second
# 882         0       3  female  22.0      0      0   10.5167        S   Third
# 885         0       3  female  39.0      0      5   29.1250        Q   Third
# 887         1       1  female  19.0      0      0   30.0000        S   First
# 888         0       3  female   NaN      1      2   23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 8    woman       False  NaN  Southampton   yes  False
# 9    child       False  NaN    Cherbourg   yes  False
# 10   child       False    G  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# 14   child       False  NaN  Southampton    no   True
# 15   woman       False  NaN  Southampton   yes   True
# 18   woman       False  NaN  Southampton    no  False
# 19   woman       False  NaN    Cherbourg   yes   True
# 22   child       False  NaN   Queenstown   yes   True
# 24   child       False  NaN  Southampton    no  False
# 25   woman       False  NaN  Southampton   yes  False
# 28   woman       False  NaN   Queenstown   yes   True
# 31   woman       False    B    Cherbourg   yes  False
# 32   woman       False  NaN   Queenstown   yes   True
# 38   woman       False  NaN  Southampton    no  False
# 39   child       False  NaN    Cherbourg   yes  False
# 40   woman       False  NaN  Southampton    no  False
# 41   woman       False  NaN  Southampton    no  False
# 43   child       False  NaN    Cherbourg   yes  False
# 44   woman       False  NaN   Queenstown   yes   True
# 47   woman       False  NaN   Queenstown   yes   True
# 49   woman       False  NaN  Southampton    no  False
# 52   woman       False    D    Cherbourg   yes  False
# 53   woman       False  NaN  Southampton   yes  False
# 56   woman       False  NaN  Southampton   yes   True
# 58   child       False  NaN  Southampton   yes  False
# 61   woman       False    B          NaN   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 807  woman       False  NaN  Southampton    no   True
# 809  woman       False    E  Southampton   yes  False
# 813  child       False  NaN  Southampton    no  False
# 816  woman       False  NaN  Southampton    no   True
# 820  woman       False    B  Southampton   yes  False
# 823  woman       False    E  Southampton   yes  False
# 829  woman       False    B          NaN   yes   True
# 830  child       False  NaN    Cherbourg   yes  False
# 835  woman       False    E    Cherbourg   yes  False
# 842  woman       False  NaN    Cherbourg   yes   True
# 849  woman       False    C    Cherbourg   yes  False
# 852  child       False  NaN    Cherbourg    no  False
# 853  woman       False    D  Southampton   yes  False
# 854  woman       False  NaN  Southampton    no  False
# 855  woman       False  NaN  Southampton   yes  False
# 856  woman       False  NaN  Southampton   yes  False
# 858  woman       False  NaN    Cherbourg   yes  False
# 862  woman       False    D  Southampton   yes   True
# 863  woman       False  NaN  Southampton    no  False
# 865  woman       False  NaN  Southampton   yes   True
# 866  woman       False  NaN    Cherbourg   yes  False
# 871  woman       False    D  Southampton   yes  False
# 874  woman       False  NaN    Cherbourg   yes  False
# 875  child       False  NaN    Cherbourg   yes   True
# 879  woman       False    C    Cherbourg   yes  False
# 880  woman       False  NaN  Southampton   yes  False
# 882  woman       False  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
#
# [314 rows x 15 columns]
# male
#      survived  pclass   sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3  male  22.0      1      0    7.2500        S   Third
# 4           0       3  male  35.0      0      0    8.0500        S   Third
# 5           0       3  male   NaN      0      0    8.4583        Q   Third
# 6           0       1  male  54.0      0      0   51.8625        S   First
# 7           0       3  male   2.0      3      1   21.0750        S   Third
# 12          0       3  male  20.0      0      0    8.0500        S   Third
.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# 6      man        True    E  Southampton    no   True
# 7    child       False  NaN  Southampton    no  False
# 12     man        True  NaN  Southampton    no   True
# 13     man        True  NaN  Southampton    no  False
# 16   child       False  NaN   Queenstown    no  False
# 17     man        True  NaN  Southampton   yes   True
# 20     man        True  NaN  Southampton    no   True
# 21     man        True    D  Southampton   yes   True
# 23     man        True    A  Southampton   yes   True
# 26     man        True  NaN    Cherbourg    no   True
# 27     man        True    C  Southampton    no  False
# 29     man        True  NaN  Southampton    no   True
# 30     man        True  NaN    Cherbourg    no   True
# 33     man        True  NaN  Southampton    no   True
# 34     man        True  NaN    Cherbourg    no  False
# 35     man        True  NaN  Southampton    no  False
# 36     man        True  NaN    Cherbourg   yes   True
# 37     man        True  NaN  Southampton    no   True
# 42     man        True  NaN    Cherbourg    no   True
# 45     man        True  NaN  Southampton    no   True
# 46     man        True  NaN   Queenstown    no  False
# 48     man        True  NaN    Cherbourg    no  False
# 50   child       False  NaN  Southampton    no  False
# 51     man        True  NaN  Southampton    no   True
# 54     man        True    B    Cherbourg    no  False
# 55     man        True    C  Southampton   yes   True
# 57     man        True  NaN    Cherbourg    no   True
# ..     ...         ...  ...          ...   ...    ...
# 840    man        True  NaN  Southampton    no   True
# 841    man        True  NaN  Southampton    no   True
# 843    man        True  NaN    Cherbourg    no   True
# 844    man        True  NaN  Southampton    no   True
# 845    man        True  NaN  Southampton    no   True
# 846    man        True  NaN  Southampton    no  False
# 847    man        True  NaN    Cherbourg    no   True
# 848    man        True  NaN  Southampton    no  False
# 850  child       False  NaN  Southampton    no  False
# 851    man        True  NaN  Southampton    no   True
# 857    man        True    E  Southampton   yes   True
# 859    man        True  NaN    Cherbourg    no   True
# 860    man        True  NaN  Southampton    no  False
# 861    man        True  NaN  Southampton    no  False
# 864    man        True  NaN  Southampton    no   True
# 867    man        True    A  Southampton    no   True
# 868    man        True  NaN  Southampton    no   True
# 869  child       False  NaN  Southampton   yes  False
# 870    man        True  NaN  Southampton    no   True
# 872    man        True    B  Southampton    no   True
# 873    man        True  NaN  Southampton    no   True
# 876    man        True  NaN  Southampton    no   True
# 877    man        True  NaN  Southampton    no   True
# 878    man        True  NaN  Southampton    no   True
# 881    man        True  NaN  Southampton    no   True
# 883    man        True  NaN  Southampton    no   True
# 884    man        True  NaN  Southampton    no   True
# 886    man        True  NaN  Southampton    no   True
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [577 rows x 15 columns]

# %%
grp.get_group('female')
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# 11          1       1  female  58.0      0      0   26.5500        S   First
# 14          0       3  female  14.0      0      0    7.8542        S   Third
.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 8    woman       False  NaN  Southampton   yes  False
# 9    child       False  NaN    Cherbourg   yes  False
# 10   child       False    G  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# 14   child       False  NaN  Southampton    no   True
# 15   woman       False  NaN  Southampton   yes   True
# 18   woman       False  NaN  Southampton    no  False
# 19   woman       False  NaN    Cherbourg   yes   True
# 22   child       False  NaN   Queenstown   yes   True
# 24   child       False  NaN  Southampton    no  False
# 25   woman       False  NaN  Southampton   yes  False
# 28   woman       False  NaN   Queenstown   yes   True
# 31   woman       False    B    Cherbourg   yes  False
# 32   woman       False  NaN   Queenstown   yes   True
# 38   woman       False  NaN  Southampton    no  False
# 39   child       False  NaN    Cherbourg   yes  False
# 40   woman       False  NaN  Southampton    no  False
# 41   woman       False  NaN  Southampton    no  False
# 43   child       False  NaN    Cherbourg   yes  False
# 44   woman       False  NaN   Queenstown   yes   True
# 47   woman       False  NaN   Queenstown   yes   True
# 49   woman       False  NaN  Southampton    no  False
# 52   woman       False    D    Cherbourg   yes  False
# 53   woman       False  NaN  Southampton   yes  False
# 56   woman       False  NaN  Southampton   yes   True
# 58   child       False  NaN  Southampton   yes  False
# 61   woman       False    B          NaN   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 807  woman       False  NaN  Southampton    no   True
# 809  woman       False    E  Southampton   yes  False
# 813  child       False  NaN  Southampton    no  False
# 816  woman       False  NaN  Southampton    no   True
# 820  woman       False    B  Southampton   yes  False
# 823  woman       False    E  Southampton   yes  False
# 829  woman       False    B          NaN   yes   True
# 830  child       False  NaN    Cherbourg   yes  False
# 835  woman       False    E    Cherbourg   yes  False
# 842  woman       False  NaN    Cherbourg   yes   True
# 849  woman       False    C    Cherbourg   yes  False
# 852  child       False  NaN    Cherbourg    no  False
# 853  woman       False    D  Southampton   yes  False
# 854  woman       False  NaN  Southampton    no  False
# 855  woman       False  NaN  Southampton   yes  False
# 856  woman       False  NaN  Southampton   yes  False
# 858  woman       False  NaN    Cherbourg   yes  False
# 862  woman       False    D  Southampton   yes   True
# 863  woman       False  NaN  Southampton    no  False
# 865  woman       False  NaN  Southampton   yes   True
# 866  woman       False  NaN    Cherbourg   yes  False
# 871  woman       False    D  Southampton   yes  False
# 874  woman       False  NaN    Cherbourg   yes  False
# 875  child       False  NaN    Cherbourg   yes   True
# 879  woman       False    C    Cherbourg   yes  False
# 880  woman       False  NaN  Southampton   yes  False
# 882  woman       False  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
#
# [314 rows x 15 columns]

# %%
grp.size()
# Out:
# sex
# female    314
# male      577
# dtype: int64

# %%
grp.aggregate(np.mean)
# Out:
#         survived    pclass        age     sibsp     parch       fare  \
# sex
# female  0.742038  2.159236  27.915709  0.694268  0.649682  44.479818
# male    0.188908  2.389948  30.726645  0.429809  0.235702  25.523893
#
#         adult_male     alone
# sex
# female    0.000000  0.401274
# male      0.930676  0.712305

# %% [markdown]
# Group by more than 1 columns?

# %%
grp = titanic.groupby(['sex', 'pclass'])

# %%
grp.groups
# Out:
# {('female',
#   1): Int64Index([  1,   3,  11,  31,  52,  61,  88, 136, 151, 166, 177, 194, 195,
#              215, 218, 230, 256, 257, 258, 268, 269, 275, 290, 291, 297, 299,
#              306, 307, 309, 310, 311, 318, 319, 325, 329, 334, 337, 341, 356,
#              366, 369, 375, 380, 383, 393, 412, 435, 457, 486, 496, 498, 504,
#              513, 520, 523, 537, 539, 540, 556, 558, 571, 577, 581, 585, 591,
#              609, 627, 641, 669, 689, 700, 708, 710, 716, 730, 742, 759, 763,
#              765, 779, 781, 796, 809, 820, 829, 835, 842, 849, 853, 856, 862,
#              871, 879, 887],
#             dtype='int64'),
#  ('female',
#   2): Int64Index([  9,  15,  41,  43,  53,  56,  58,  66,  84,  98, 123, 133, 161,
#              190, 199, 211, 237, 247, 259, 272, 303, 312, 316, 322, 323, 327,
#              345, 346, 357, 387, 389, 399, 416, 417, 426, 427, 432, 437, 440,
#              443, 446, 458, 472, 473, 506, 516, 518, 526, 530, 535, 546, 576,
#              580, 596, 600, 608, 615, 618, 635, 651, 670, 706, 717, 720, 726,
#              747, 750, 754, 772, 774, 801, 854, 865, 866, 874, 880],
#             dtype='int64'),
#  ('female', 3): Int64Index([  2,   8,  10,  14,  18,  19,  22,  24,  25,  28,
#              ...
#              823, 830, 852, 855, 858, 863, 875, 882, 885, 888],
#             dtype='int64', length=144),
#  ('male', 1): Int64Index([  6,  23,  27,  30,  34,  35,  54,  55,  62,  64,
#              ...
#              793, 802, 806, 815, 822, 839, 857, 867, 872, 889],
#             dtype='int64', length=122),
#  ('male', 2): Int64Index([ 17,  20,  21,  33,  70,  72,  78,  99, 117, 120,
#              ...
#              812, 817, 827, 831, 841, 848, 861, 864, 883, 886],
#             dtype='int64', length=108),
#  ('male', 3): Int64Index([  0,   4,   5,   7,  12,  13,  16,  26,  29,  36,
#              ...
#              868, 869, 870, 873, 876, 877, 878, 881, 884, 890],
#             dtype='int64', length=347)}

# %% [markdown]
# Often after creating groups, we want to do some calculation for each group.

# %% [markdown]
# e.g. Calculate the average age of each sex?

# %%
grp = titanic.groupby('sex').mean()

# %%
grp
# Out:
#         survived    pclass        age     sibsp     parch       fare  \
# sex
# female  0.742038  2.159236  27.915709  0.694268  0.649682  44.479818
# male    0.188908  2.389948  30.726645  0.429809  0.235702  25.523893
#
#         adult_male     alone
# sex
# female    0.000000  0.401274
# male      0.930676  0.712305

# %% [markdown]
# The group names are used as the new index.
#
# Can be changed using the `reset_index` method

# %%
grp.reset_index()
# Out:
#       sex  survived    pclass        age     sibsp     parch       fare  \
# 0  female  0.742038  2.159236  27.915709  0.694268  0.649682  44.479818
# 1    male  0.188908  2.389948  30.726645  0.429809  0.235702  25.523893
#
#    adult_male     alone
# 0    0.000000  0.401274
# 1    0.930676  0.712305

# %% [markdown]
# Alternatively:

# %%
grp = titanic.groupby('sex').agg(np.mean)
grp.reset_index()
# Out:
#       sex  survived    pclass        age     sibsp     parch       fare  \
# 0  female  0.742038  2.159236  27.915709  0.694268  0.649682  44.479818
# 1    male  0.188908  2.389948  30.726645  0.429809  0.235702  25.523893
#
#    adult_male     alone
# 0    0.000000  0.401274
# 1    0.930676  0.712305

# %% [markdown]
# Applying multiple calculations

# %%
grp = titanic.groupby('sex')
grp['age'].agg([np.sum, np.mean, np.std]).reset_index()
# Out:
#       sex       sum       mean        std
# 0  female   7286.00  27.915709  14.110146
# 1    male  13919.17  30.726645  14.678201
