# %% [markdown]
# # Bins

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import vega_datasets
# %matplotlib inline

# %%
#Let's use movies data and capure movie ratings without NAN
IMDB_ratings_clean = movies.IMDB_Rating.dropna()
IMDB_ratings_clean.plot()

# %%
x=IMDB_ratings_clean

# %%
# Add random data to create non-normalized dataset
data_rand=np.random.normal(size=1000)
#Let's combine the ratings with random data
sum_array=np.asarray(np.concatenate((x, data_rand)))

# %%
#the following histograms are ordered by the number of created bins from 64 to 13

# %%
plt.title("Histogram with 'sqrt' bins")
plt.hist(sum_array,bins='sqrt')
# Out:
# (array([  1.,   1.,   1.,   5.,   5.,   5.,   6.,  17.,  24.,  32.,  33.,
#          66.,  51.,  81.,  59.,  72.,  71.,  79.,  81.,  70.,  55.,  48.,
#          43.,  26.,  26.,  22.,  13.,  13.,  11.,  15.,   8.,  12.,  10.,
#          32.,  19.,  11.,  24.,  31.,  32.,  46.,  80.,  84.,  85., 110.,
#         125., 155., 158., 195., 185., 100., 186., 213., 189., 186., 164.,
#         145., 113., 101.,  64.,  45.,  21.,  17.,   7.,   3.]),
#  array([-3.15037915, -2.95740447, -2.7644298 , -2.57145513, -2.37848045,
#         -2.18550578, -1.9925311 , -1.79955643, -1.60658176, -1.41360708,
#         -1.22063241, -1.02765773, -0.83468306, -0.64170838, -0.44873371,
#         -0.25575904, -0.06278436,  0.13019031,  0.32316499,  0.51613966,
#          0.70911434,  0.90208901,  1.09506368,  1.28803836,  1.48101303,
#          1.67398771,  1.86696238,  2.05993705,  2.25291173,  2.4458864 ,
#          2.63886108,  2.83183575,  3.02481043,  3.2177851 ,  3.41075977,
# ...

# %%
plt.title("Histogram with 'rice' bins")
plt.hist(sum_array,bins='rice')
# Out:
# (array([  2.,   6.,  10.,  23.,  56.,  99., 132., 131., 150., 151., 103.,
#          69.,  48.,  26.,  26.,  20.,  42.,  30.,  55.,  78., 164., 195.,
#         280., 353., 285., 399., 375., 309., 214., 109.,  38.,  10.]),
#  array([-3.15037915, -2.7644298 , -2.37848045, -1.9925311 , -1.60658176,
#         -1.22063241, -0.83468306, -0.44873371, -0.06278436,  0.32316499,
#          0.70911434,  1.09506368,  1.48101303,  1.86696238,  2.25291173,
#          2.63886108,  3.02481043,  3.41075977,  3.79670912,  4.18265847,
#          4.56860782,  4.95455717,  5.34050652,  5.72645586,  6.11240521,
#          6.49835456,  6.88430391,  7.27025326,  7.65620261,  8.04215195,
#          8.4281013 ,  8.81405065,  9.2       ]),
#  <a list of 32 Patch objects>)

# %%
plt.title("Histogram with 'auto' bins")
plt.hist(sum_array,bins='auto')
# Out:
# (array([  3.,  16.,  47., 139., 199., 223., 210., 105.,  56.,  38.,  39.,
#          73.,  85., 229., 357., 522., 592., 539., 359., 130.,  27.]),
#  array([-3.15037915, -2.56226586, -1.97415256, -1.38603927, -0.79792598,
#         -0.20981268,  0.37830061,  0.9664139 ,  1.55452719,  2.14264049,
#          2.73075378,  3.31886707,  3.90698036,  4.49509366,  5.08320695,
#          5.67132024,  6.25943354,  6.84754683,  7.43566012,  8.02377341,
#          8.61188671,  9.2       ]),
#  <a list of 21 Patch objects>)

# %%
plt.title("Histogram with 'fd' bins")
plt.hist(sum_array,bins='fd')
# Out:
# (array([  3.,  16.,  47., 139., 199., 223., 210., 105.,  56.,  38.,  39.,
#          73.,  85., 229., 357., 522., 592., 539., 359., 130.,  27.]),
#  array([-3.15037915, -2.56226586, -1.97415256, -1.38603927, -0.79792598,
#         -0.20981268,  0.37830061,  0.9664139 ,  1.55452719,  2.14264049,
#          2.73075378,  3.31886707,  3.90698036,  4.49509366,  5.08320695,
#          5.67132024,  6.25943354,  6.84754683,  7.43566012,  8.02377341,
#          8.61188671,  9.2       ]),
#  <a list of 21 Patch objects>)

# %%
plt.title("Histogram with 'scott' bins")
plt.hist(sum_array,bins='scott')
# Out:
# (array([  5.,  17.,  76., 189., 230., 253., 154.,  67.,  41.,  43.,  73.,
#         144., 258., 504., 565., 689., 422., 223.,  35.]),
#  array([-3.15037915, -2.50035919, -1.85033924, -1.20031928, -0.55029933,
#          0.09972063,  0.74974058,  1.39976054,  2.04978049,  2.69980045,
#          3.3498204 ,  3.99984036,  4.64986031,  5.29988027,  5.94990022,
#          6.59992018,  7.24994013,  7.89996009,  8.54998004,  9.2       ]),
#  <a list of 19 Patch objects>)

# %%
plt.title("Histogram with 'doane' bins")
plt.hist(sum_array,bins='doane')
# Out:
# (array([  7.,  17.,  93., 220., 248., 252., 121.,  55.,  39.,  72.,  87.,
#         251., 434., 638., 688., 508., 223.,  35.]),
#  array([-3.15037915, -2.46424697, -1.7781148 , -1.09198262, -0.40585045,
#          0.28028173,  0.9664139 ,  1.65254608,  2.33867825,  3.02481043,
#          3.7109426 ,  4.39707478,  5.08320695,  5.76933913,  6.4554713 ,
#          7.14160348,  7.82773565,  8.51386783,  9.2       ]),
#  <a list of 18 Patch objects>)

# %%
plt.title("Histogram with 'sturges' bins")
plt.hist(sum_array,bins='sturges')
# Out:
# (array([ 12.,  80., 281., 363., 211.,  76.,  71., 139., 383., 818., 874.,
#         587.,  93.]),
#  array([-3.15037915, -2.20034998, -1.25032082, -0.30029165,  0.64973751,
#          1.59976668,  2.54979584,  3.49982501,  4.44985417,  5.39988334,
#          6.3499125 ,  7.29994167,  8.24997083,  9.2       ]),
#  <a list of 13 Patch objects>)

# %%
# The auto and fd produced the same 21 number of bins, sqrt and rice significantly overestimated (64 and 32 respectively) and 
# sturges - underestimated the number of bins, hiding major number of data points

# %%
from matplotlib import mlab
import matplotlib.pyplot as plt
import numpy as np



#d = np.sort(np.random.randint(0,1000,1000)).cumsum()
d=sum_array
# Percentile values
p = np.array([0.0, 25.0, 50.0, 75.0, 100.0])

perc = mlab.prctile(d, p=p)

#plt.hist(d, cumulative=True)

# Place red dots on the percentiles
plt.plot((len(d)-1) * p/100., perc, 'ro')

# Set tick locations and labels
plt.xticks((len(d)-1) * p/100., map(str, p))

plt.show()
# Out:
# C:\Users\yyezeret\AppData\Local\Continuum\Anaconda2\envs\dviz\lib\site-packages\ipykernel_launcher.py:12: MatplotlibDeprecationWarning: numpy.percentile
#   if sys.path[0] == '':

# %%
data_rand=np.random.normal(size=1000)

# %%
# Let's build our plot
 
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()  # set up the 2nd axis
ax1.plot((len(d)-1) * p/100., perc, 'ro')
ax2.hist(data_rand, density=True, cumulative=True,histtype='step')

ax1.set_title('Percentiles')
ax1.set_ylabel('Percentiles')
ax2.set_ylabel('Cumulative Percentile')
fig.tight_layout()
plt.show()

# %%
plt.hist(data_rand, density=True, cumulative=True,histtype='step')
# Out:
# (array([0.003, 0.014, 0.072, 0.189, 0.435, 0.69 , 0.89 , 0.978, 0.996,
#         1.   ]),
#  array([-3.67146102, -2.9747886 , -2.27811618, -1.58144376, -0.88477135,
#         -0.18809893,  0.50857349,  1.20524591,  1.90191832,  2.59859074,
#          3.29526316]),
#  <a list of 1 Patch objects>)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import mlab

np.random.seed(0)

mu = 200
sigma = 25
n_bins = 50
x = np.random.normal(mu, sigma, size=100)

fig, ax = plt.subplots(figsize=(8, 4))

# plot the cumulative histogram
n, bins, patches = ax.hist(x, n_bins, density=True, histtype='step',
                           cumulative=True, label='Empirical')

# Add a line showing the expected distribution.
y = mlab.normpdf(bins, mu, sigma).cumsum()
y /= y[-1]

ax.plot(bins, y, 'k--', linewidth=1.5, label='Theoretical')

# Overlay a reversed cumulative histogram.
ax.hist(x, bins=bins, density=True, histtype='step', cumulative=-1,
        label='Reversed emp.')

# tidy up the figure
ax.grid(True)
ax.legend(loc='right')
ax.set_title('Cumulative step histograms')
ax.set_xlabel('Annual rainfall (mm)')
ax.set_ylabel('Likelihood of occurrence')

plt.show()
# Out:
# C:\Users\yyezeret\AppData\Local\Continuum\Anaconda2\envs\dviz\lib\site-packages\ipykernel_launcher.py:19: MatplotlibDeprecationWarning: scipy.stats.norm.pdf

# %%
# Out:
# C:\Users\yyezeret\AppData\Local\Continuum\Anaconda2\envs\dviz\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
